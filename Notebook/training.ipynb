# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'D:\Programmer\Project\Mental Health predictor\data\Student Social Media And Mental Health Impact.csv')
df.head()
# Out:
#    Age  Gender Country Academic_Level Most_Used_Platform Purpose_Of_Use  \
# 0   21    Male   Other  Undergraduate           Facebook     Networking
# 1   23  Female   Other       Graduate           LinkedIn      Education
# 2   22    Male  Canada  Undergraduate          Instagram  Entertainment
# 3   18    Male   Other    High School           Snapchat  Entertainment
# 4   24  Female   Other       Graduate           Facebook     Networking
#
#    Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  Physical_Activity_Hours  \
# 0                    4.0            134          4.5                      2.2
# 1                    1.6             73          7.0                      2.4
# 2                    4.6            166          4.0                      1.8
# 3                    7.0            220          1.0                      1.7
# 4                    7.5            237          1.0                      1.1
#
#    Sleep_Hours_Per_Night Stress_Level  Mental_Health_Score
# ...

# %%
df.shape
# Out:
# (5000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      5000 non-null   int64
#  1   Gender                   5000 non-null   object
#  2   Country                  5000 non-null   object
#  3   Academic_Level           5000 non-null   object
#  4   Most_Used_Platform       5000 non-null   object
#  5   Purpose_Of_Use           5000 non-null   object
#  6   Avg_Daily_Usage_Hours    5000 non-null   float64
#  7   Daily_Unlocks            5000 non-null   int64
#  8   Study_Hours              5000 non-null   float64
#  9   Physical_Activity_Hours  5000 non-null   float64
#  10  Sleep_Hours_Per_Night    5000 non-null   float64
#  11  Stress_Level             5000 non-null   object
#  12  Mental_Health_Score      5000 non-null   float64
# dtypes: float64(5), int64(2), object(6)
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Academic_Level', 'Most_Used_Platform',
#        'Purpose_Of_Use', 'Avg_Daily_Usage_Hours', 'Daily_Unlocks',
#        'Study_Hours', 'Physical_Activity_Hours', 'Sleep_Hours_Per_Night',
#        'Stress_Level', 'Mental_Health_Score'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age                        0
# Gender                     0
# Country                    0
# Academic_Level             0
# Most_Used_Platform         0
# Purpose_Of_Use             0
# Avg_Daily_Usage_Hours      0
# Daily_Unlocks              0
# Study_Hours                0
# Physical_Activity_Hours    0
# Sleep_Hours_Per_Night      0
# Stress_Level               0
# Mental_Health_Score        0
# dtype: int64

# %%
df['Academic_Level'].value_counts()
# Out:
# Academic_Level
# Undergraduate    3632
# Graduate          918
# High School       450
# Name: count, dtype: int64

# %%
df['Academic_Level'].value_counts().plot(kind='bar', figsize=(10, 5))
# Out:
# <Axes: xlabel='Academic_Level'>

# %%
#df['Academic_Level'] = df['Academic_Level'].map({'High School': 1, 'Undergraduate': 2, 'Graduate': 3})

# %%
df.head(20)
# Out:
#     Age  Gender    Country Academic_Level Most_Used_Platform Purpose_Of_Use  \
# 0    21    Male      Other  Undergraduate           Facebook     Networking
# 1    23  Female      Other       Graduate           LinkedIn      Education
# 2    22    Male     Canada  Undergraduate          Instagram  Entertainment
# 3    18    Male      Other    High School           Snapchat  Entertainment
# 4    24  Female      Other       Graduate           Facebook     Networking
# 5    19  Female      Other  Undergraduate            Twitter           News
# 6    22  Female      Other  Undergraduate          Instagram  Entertainment
# 7    21  Female      Other  Undergraduate           Facebook     Networking
# 8    24    Male        USA       Graduate            YouTube      Education
# 9    19    Male      Other  Undergraduate             TikTok  Entertainment
# 10   18    Male      Other    High School           LinkedIn      Education
# ...

# %%
df.describe()
# Out:
#               Age  Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  \
# count  5000.00000            5000.000000    5000.000000  5000.000000
# mean     20.82180               5.078460     171.452600     3.008420
# std       1.73662               1.653913      42.858254     1.637018
# min      18.00000               1.000000      62.000000     0.300000
# 25%      19.00000               3.800000     140.000000     1.500000
# 50%      21.00000               5.000000     171.000000     2.800000
# 75%      22.00000               6.300000     204.000000     4.200000
# max      24.00000               8.800000     273.000000     8.300000
#
#        Physical_Activity_Hours  Sleep_Hours_Per_Night  Mental_Health_Score
# count              5000.000000            5000.000000          5000.000000
# mean                  1.751000               6.634580             6.230980
# std                   0.668398               1.221391             1.278701
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
#df['Academic_Level'] = df['Academic_Level'].astype(int)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      2635
# Female    2365
# Name: count, dtype: int64

# %%
#df['Gender'] = df['Gender'].map({'Male':0, 'Female':1})

# %%
plt.figure(figsize=(18, 12))
plt.pie(df['Country'].value_counts(), labels=df['Country'].value_counts().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x2898af88b30>,
# ...
#  [Text(0.41775695221608966, 1.017584949218061, 'Other'),
#   Text(-0.9464643273515035, 0.5605401654217707, 'India'),
#   Text(-1.0975150135853773, 0.0738971917916309, 'USA'),
#   Text(-1.0507607085464243, -0.32542577245051857, 'Canada'),
#   Text(-0.9265319353924022, -0.5929068836655632, 'Australia'),
#   Text(-0.7585255590270034, -0.7966423139042843, 'UK'),
#   Text(-0.5835619704363894, -0.9324459376609449, 'Germany'),
#   Text(-0.44319685326768227, -1.0067653893800803, 'Mexico'),
#   Text(-0.32146162715577853, -1.0519802385341464, 'Turkey'),
#   Text(-0.20000562289660645, -1.081664342950132, 'France'),
#   Text(-0.08354800787168035, -1.0968225610282976, 'Spain'),
#   Text(0.029716799016926275, -1.099598523032924, 'Ireland'),
#   Text(0.13855298611422762, -1.0912392359326304, 'Denmark'),
#   Text(0.24332931923226217, -1.0727491982760762, 'Japan'),
#   Text(0.343204072880183, -1.0450889743741698, 'Switzerland'),
# ...

# %%
plt.pie(df['Most_Used_Platform'].value_counts(), labels=df['Most_Used_Platform'].value_counts().index, autopct='%1.1f%%', startangle=90, shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2898ee4bd40>,
# ...
#  [Text(-0.717017116965619, 0.8341980903708135, 'Instagram'),
#   Text(-1.0016883505273508, -0.4545552204273924, 'TikTok'),
#   Text(-0.1275747012008025, -1.0925770890941866, 'Facebook'),
#   Text(0.6780143810551653, -0.8661965706941935, 'LinkedIn'),
#   Text(1.0602804258914331, -0.2929256193498301, 'YouTube'),
#   Text(1.0409171701318505, 0.35565635791406897, 'Twitter'),
#   Text(0.6979661538721541, 0.8502018866415862, 'Snapchat'),
#   Text(0.33926142315597924, 1.0463754998843293, 'WhatsApp'),
#   Text(0.18844117567226298, 1.0837388630621565, 'LINE'),
#   Text(0.12688818761319556, 1.0926570312061505, 'VKontakte'),
#   Text(0.0745869208343629, 1.0974683554619917, 'KakaoTalk'),
#   Text(0.024879203512837376, 1.0997186118423963, 'WeChat')],
#  [Text(-0.3911002456176103, 0.45501714020226186, '22.6%'),
#   Text(-0.5463754639240095, -0.247939211142214, '18.4%'),
#   Text(-0.06958620065498318, -0.5959511395059199, '14.4%'),
# ...

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Academic_Level', 'Most_Used_Platform',
#        'Purpose_Of_Use', 'Avg_Daily_Usage_Hours', 'Daily_Unlocks',
#        'Study_Hours', 'Physical_Activity_Hours', 'Sleep_Hours_Per_Night',
#        'Stress_Level', 'Mental_Health_Score'],
#       dtype='object')

# %%
df['Stress_Level'].value_counts()
# Out:
# Stress_Level
# Very High    1621
# High         1440
# Medium       1295
# Low           644
# Name: count, dtype: int64

# %%
#df['Stress_Level'] = df['Stress_Level'].map({'Low': 1, 'Medium': 2, 'High': 3,"Very High":4})

# %%
df.head()
# Out:
#    Age  Gender Country Academic_Level Most_Used_Platform Purpose_Of_Use  \
# 0   21    Male   Other  Undergraduate           Facebook     Networking
# 1   23  Female   Other       Graduate           LinkedIn      Education
# 2   22    Male  Canada  Undergraduate          Instagram  Entertainment
# 3   18    Male   Other    High School           Snapchat  Entertainment
# 4   24  Female   Other       Graduate           Facebook     Networking
#
#    Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  Physical_Activity_Hours  \
# 0                    4.0            134          4.5                      2.2
# 1                    1.6             73          7.0                      2.4
# 2                    4.6            166          4.0                      1.8
# 3                    7.0            220          1.0                      1.7
# 4                    7.5            237          1.0                      1.1
#
#    Sleep_Hours_Per_Night Stress_Level  Mental_Health_Score
# ...

# %%
sns.boxplot(x='Stress_Level', y='Sleep_Hours_Per_Night', data=df, palette='Set1')
# Out:
# <Axes: xlabel='Stress_Level', ylabel='Sleep_Hours_Per_Night'>

# %%
sns.boxplot(x='Stress_Level', y='Mental_Health_Score', data=df, palette='Set2')
# Out:
# <Axes: xlabel='Stress_Level', ylabel='Mental_Health_Score'>

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Academic_Level', 'Most_Used_Platform',
#        'Purpose_Of_Use', 'Avg_Daily_Usage_Hours', 'Daily_Unlocks',
#        'Study_Hours', 'Physical_Activity_Hours', 'Sleep_Hours_Per_Night',
#        'Stress_Level', 'Mental_Health_Score'],
#       dtype='object')

# %%
sns.scatterplot(y='Mental_Health_Score', x='Avg_Daily_Usage_Hours', data=df,                 hue='Stress_Level', palette='Set2', alpha=0.9)
# Out:
# <Axes: xlabel='Avg_Daily_Usage_Hours', ylabel='Mental_Health_Score'>

# %%
sns.scatterplot(x='Sleep_Hours_Per_Night', y='Avg_Daily_Usage_Hours', data=df,hue='Stress_Level', palette='Set1', alpha=0.9)
# Out:
# <Axes: xlabel='Sleep_Hours_Per_Night', ylabel='Avg_Daily_Usage_Hours'>

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Most_Used_Platform', data=df, palette='Set2', order=df['Most_Used_Platform'].value_counts().index)
# Out:
# <Axes: xlabel='Most_Used_Platform', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Academic_Level', 'Most_Used_Platform',
#        'Purpose_Of_Use', 'Avg_Daily_Usage_Hours', 'Daily_Unlocks',
#        'Study_Hours', 'Physical_Activity_Hours', 'Sleep_Hours_Per_Night',
#        'Stress_Level', 'Mental_Health_Score'],
#       dtype='object')

# %%
sns.scatterplot(x='Physical_Activity_Hours', y='Mental_Health_Score', data=df, hue='Stress_Level', palette='viridis', alpha=0.7)
# Out:
# <Axes: xlabel='Physical_Activity_Hours', ylabel='Mental_Health_Score'>

# %%
num_features = df.select_dtypes(include=[np.number])
Q1 = num_features.quantile(0.25)
Q3 = num_features.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = ((num_features < lower_bound) | (num_features > upper_bound))

# %%
print("Outliers in each feature:", outliers.sum())
# Out:
# Outliers in each feature: Age                         0
# Avg_Daily_Usage_Hours       0
# Daily_Unlocks               0
# Study_Hours                 2
# Physical_Activity_Hours    22
# Sleep_Hours_Per_Night       0
# Mental_Health_Score         0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (4998, 13)

# %%
#convert negative values to positive values or unrealistic values to realistic values
df['Physical_Activity_Hours'] = df['Physical_Activity_Hours'].apply(lambda x: abs(x) if x < 0 else x)

# %%
df.describe()
# Out:
#                Age  Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  \
# count  4998.000000            4998.000000    4998.000000  4998.000000
# mean     20.822129               5.078491     171.455582     3.008403
# std       1.736774               1.654097      42.859829     1.636831
# min      18.000000               1.000000      62.000000     0.300000
# 25%      19.000000               3.800000     140.000000     1.500000
# 50%      21.000000               5.000000     171.000000     2.800000
# 75%      22.000000               6.300000     204.000000     4.200000
# max      24.000000               8.800000     273.000000     8.300000
#
#        Physical_Activity_Hours  Sleep_Hours_Per_Night  Mental_Health_Score
# count              4998.000000            4998.000000          4998.000000
# mean                  1.751561               6.634654             6.231152
# std                   0.666305               1.221561             1.278476
# ...

# %%
num_cols = df.select_dtypes(include=[np.number])
num_cols.skew()
# Out:
# Age                        0.155008
# Avg_Daily_Usage_Hours      0.005575
# Daily_Unlocks              0.002309
# Study_Hours                0.436125
# Physical_Activity_Hours    0.062494
# Sleep_Hours_Per_Night      0.123919
# Mental_Health_Score        0.207086
# dtype: float64

# %%
top_countries = df['Country'].value_counts().index[:10].tolist()

# %%
def group_other_countries(country):
    if country in top_countries:
        return country
    else:
        return 'Other'

# %%
df['Country'] = df['Country'].apply(group_other_countries)

# %%
df['Country'].value_counts()
# Out:
# Country
# Other        3231
# India         389
# USA           354
# Canada        230
# Australia     198
# UK            185
# Germany       136
# Mexico         94
# Turkey         94
# France         87
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Academic_Level', 'Most_Used_Platform',
#        'Purpose_Of_Use', 'Avg_Daily_Usage_Hours', 'Daily_Unlocks',
#        'Study_Hours', 'Physical_Activity_Hours', 'Sleep_Hours_Per_Night',
#        'Stress_Level', 'Mental_Health_Score'],
#       dtype='object')

# %%
# standardize the column name to match the rest of the notebook
df['Purpose_Of_Use'].value_counts()
# Out:
# Purpose_Of_Use
# Entertainment    2551
# Education        1093
# Networking        793
# News              561
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split



skewed_col = ['Study_Hours']
other_numeric_cols = ['Sleep_Hours_Per_Night', 'Avg_Daily_Usage_Hours', 'Physical_Activity_Hours', 'Age','Daily_Unlocks']
ordinal_col = ['Stress_Level']
normal_cols = ['Gender', 'Academic_Level', 'Country', 'Most_Used_Platform', 'Purpose_Of_Use',]
feature_cols = skewed_col + other_numeric_cols + ordinal_col + normal_cols
X = df[feature_cols]
y = df['Mental_Health_Score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# ### preprocessor pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer, StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# 1. skewed features: Apply log transformation to reduce skewness
skewed_features = Pipeline(steps=[
    ('log_transform', FunctionTransformer(np.log1p, validate=True)),
    ('scaler', StandardScaler())
])
# 2. other numeric features: Apply standard scaling
plain_numeric_features = Pipeline(steps=[
    ('scaler', StandardScaler())
])
 
# 3. ordinal features: Apply ordinal encoding
ordinal_features = Pipeline(steps=[
    ('ordinal_encoder', OrdinalEncoder(categories=[['Low', 'Medium', 'High', 'Very High']])),
    ('scaler', StandardScaler())
])  

# 4. normal features: Apply one-hot encoding
normal_features = Pipeline(steps=[
    ('onehot_encoder', OneHotEncoder(handle_unknown='ignore')),
    ('scaler', StandardScaler(with_mean=False))
])


preprocessor = ColumnTransformer(transformers=[ 
    ('skewed', skewed_features,skewed_col),
    ('plain_numeric', plain_numeric_features, other_numeric_cols),
    ('ordinal', ordinal_features, ordinal_col),
    ('normal', normal_features, normal_cols)
])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

lr_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

lr_pipeline.fit(X_train, y_train)
lr_preds       = lr_pipeline.predict(X_test)
lr_preds_train = lr_pipeline.predict(X_train)

lr_r2_testing  = r2_score(y_test, lr_preds)
lr_r2_training = r2_score(y_train, lr_preds_train)
lr_mae         = mean_absolute_error(y_test, lr_preds)

print(f"Accuracy of Training {lr_r2_training}")
print(f"Accuracy of Testing {lr_r2_testing}")
print(f'MAE {lr_mae}')
# Out:
# Accuracy of Training 0.7236746954118218
# Accuracy of Testing 0.7397919875291039
# MAE 0.5361864744079625

# %%
from sklearn.ensemble import RandomForestRegressor

rf_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('random forest', RandomForestRegressor(random_state=42))
])

rf_pipeline.fit(X_train, y_train)
rf_preds          = rf_pipeline.predict(X_test)
rf_preds_training = rf_pipeline.predict(X_train)

rf_r2_testing  = r2_score(y_test, rf_preds)
rf_r2_training = r2_score(y_train, rf_preds_training)
rf_mae         = mean_absolute_error(y_test, rf_preds)

print(f"Accuracy of Training {rf_r2_training}")
print(f"Accuracy of Testing {rf_r2_testing}")
print(f"MAE : {rf_mae}")
# Out:
# Accuracy of Training 0.9807029120580137
# Accuracy of Testing 0.8777578014965457
# MAE : 0.3468539333333334

# %%
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'random forest__n_estimators'       : [100,200,300],
    'random forest__max_depth'         : [3,5,9],
    'random forest__min_samples_split' : [2,5,10],
    'random forest__min_samples_leaf'  : [1,2,4]
}

random_search = RandomizedSearchCV(
    estimator=rf_pipeline,
    param_distributions=param_grid,
    n_iter = 20,
    cv = 5,
    scoring='r2',
    random_state=42,
    n_jobs =-1 #processor free
)

random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('skewed',
#                                                                                Pipeline(steps=[('log_transform',
#                                                                                                 FunctionTransformer(func=<ufunc 'log1p'>,
#                                                                                                                     validate=True)),
#                                                                                                ('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                ['Study_Hours']),
#                                                                               ('plain_numeric',
# ...

# %%
random_search.best_params_
# Out:
# {'random forest__n_estimators': 200,
#  'random forest__min_samples_split': 2,
#  'random forest__min_samples_leaf': 1,
#  'random forest__max_depth': 9}

# %%
rf_best_pipeline = random_search.best_estimator_
rf_best_preds    = rf_best_pipeline.predict(X_test)

print(f"R2 Score for random forest after hyperparameter tuning {r2_score(y_test, rf_best_preds)}")
print(f"MAE Score for random forest after hyperparameter tuning {mean_absolute_error(y_test, rf_best_preds)}")
# Out:
# R2 Score for random forest after hyperparameter tuning 0.8310498712061127
# MAE Score for random forest after hyperparameter tuning 0.4219272509626956

# %%
from sklearn.metrics import mean_squared_error

# Calculate RMSE for Linear Regression
lr_rmse = np.sqrt(mean_squared_error(y_test, lr_preds))

# Calculate RMSE for default Random Forest
rf_rmse = np.sqrt(mean_squared_error(y_test, rf_preds))

# Calculate RMSE for tuned Random Forest
rf_tuned_preds          = random_search.best_estimator_.predict(X_test)
rf_tuned_rmse           = np.sqrt(mean_squared_error(y_test, rf_tuned_preds))
rf_tuned_training_preds = random_search.best_estimator_.predict(X_train)
r2_tuned_training       = r2_score(y_train, rf_tuned_training_preds)
rf_tuned_mae            = mean_absolute_error(y_test, rf_tuned_preds)
rf_tuned_r2             = r2_score(y_test, rf_tuned_preds)


# Create a DataFrame to consolidate results
results = pd.DataFrame({
    'Model': ['Linear Regression', 'Random Forest (default)', 'Random Forest (tuned)'],
    'R2': [lr_r2_testing, rf_r2_testing, rf_tuned_r2],
    'Training R2': [lr_r2_training, rf_r2_training, r2_tuned_training],
    'MAE': [lr_mae, rf_mae, rf_tuned_mae],
    'RMSE': [lr_rmse, rf_rmse, rf_tuned_rmse]
})

print(results)
# Out:
#                      Model        R2  Training R2       MAE      RMSE
# 0        Linear Regression  0.739792     0.723675  0.536186  0.676035
# 1  Random Forest (default)  0.877758     0.980703  0.346854  0.463361
# 2    Random Forest (tuned)  0.831050     0.883224  0.421927  0.544739

# %%
import joblib

# Save the best model
joblib.dump(random_search.best_estimator_, 'best_random_forest_model.pkl')
# Out:
# ['best_random_forest_model.pkl']
